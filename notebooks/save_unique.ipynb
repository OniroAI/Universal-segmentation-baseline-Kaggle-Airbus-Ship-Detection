# %%
#https://www.kaggle.com/manuscrits/create-a-validation-dataset-correcting-the-leak#

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
print(os.listdir("../../data/"))

# Any results you write to the current directory are saved as output.
# Out:
# ['sample_submission.csv', 'train_ship_segmentations.csv', 'train_small', 'test_small', 'ships_small.zip', 'train_ships_small.csv', 'models', 'samples_with_ships.csv', 'train_v2.zip', 'train', '.torch', 'test_v2.zip', 'test', 'submissions']

# %%
df = pd.read_csv("../../data/train/train_ship_segmentations_v2.csv")
dfWtShipOnly = df.drop( df.index[df.EncodedPixels.apply(lambda x: not isinstance(x, str)).tolist()])

# %% [markdown]
# # Creating the clean dataset (with boat only)

# %%
# Use rle and its position in the image as identifier of the image
dfWtShipOnly["rleAndPosition"] = dfWtShipOnly.EncodedPixels.apply(lambda x: ' '.join(x.split(" ")[1::2]) + ' ' + ' '.join([ str(int(hor) % 256) for hor in x.split(" ")[0::2]]) if (isinstance(x, str)) else x)
dfWtShipOnly.head()
# Out:
#          ImageId                                      EncodedPixels  \
# 2  000155de5.jpg  264661 17 265429 33 266197 33 266965 33 267733...
# 3  000194a2d.jpg  360486 1 361252 4 362019 5 362785 8 363552 10 ...
# 4  000194a2d.jpg  51834 9 52602 9 53370 9 54138 9 54906 9 55674 ...
# 5  000194a2d.jpg  198320 10 199088 10 199856 10 200624 10 201392...
# 6  000194a2d.jpg  55683 1 56451 1 57219 1 57987 1 58755 1 59523 ...
#
#                                       rleAndPosition
# 2  17 33 33 33 33 33 33 33 33 33 33 33 33 33 33 3...
# 3  1 4 5 8 10 10 9 10 10 9 9 10 10 9 9 9 10 9 9 7...
# 4  9 9 9 9 9 7 7 7 7 7 7 7 9 9 9 9 9 9 122 122 12...
# 5  10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 1...
# 6          1 1 1 1 1 1 1 131 131 131 131 131 131 131

# %%
#List in a new column all the ImageId where the 'rleAndPosition' occurs.
dfWtShipOnly["allSameRle"] = dfWtShipOnly["rleAndPosition"].apply(lambda x: dfWtShipOnly.ImageId[dfWtShipOnly["rleAndPosition"] == x].tolist())
dfWtShipOnly.head(10)
# Out:
#           ImageId                                      EncodedPixels  \
# 2   000155de5.jpg  264661 17 265429 33 266197 33 266965 33 267733...
# 3   000194a2d.jpg  360486 1 361252 4 362019 5 362785 8 363552 10 ...
# 4   000194a2d.jpg  51834 9 52602 9 53370 9 54138 9 54906 9 55674 ...
# 5   000194a2d.jpg  198320 10 199088 10 199856 10 200624 10 201392...
# 6   000194a2d.jpg  55683 1 56451 1 57219 1 57987 1 58755 1 59523 ...
# 7   000194a2d.jpg  254389 9 255157 17 255925 17 256693 17 257461 ...
# 9   00021ddc3.jpg  108287 1 109054 3 109821 4 110588 5 111356 5 1...
# 10  00021ddc3.jpg  101361 1 102128 3 102896 4 103663 6 104430 9 1...
# 11  00021ddc3.jpg  74441 3 75207 5 75975 5 76743 5 77511 5 78280 ...
# 12  00021ddc3.jpg  74444 4 75212 4 75980 4 76748 4 77517 3 78285 ...
#
#                                        rleAndPosition  \
# 2   17 33 33 33 33 33 33 33 33 33 33 33 33 33 33 3...
# 3   1 4 5 8 10 10 9 10 10 9 9 10 10 9 9 9 10 9 9 7...
# 4   9 9 9 9 9 7 7 7 7 7 7 7 9 9 9 9 9 9 122 122 12...
# 5   10 10 10 10 10 10 10 10 10 10 10 10 10 10 10 1...
# 6           1 1 1 1 1 1 1 131 131 131 131 131 131 131
# 7   9 17 17 17 17 17 17 17 17 17 18 17 17 17 17 17...
# 9   1 3 4 5 5 6 7 8 9 10 11 12 12 13 14 14 14 15 1...
# 10  1 3 4 6 9 10 1 14 14 14 14 14 14 14 14 14 14 1...
# 11  3 5 5 5 5 4 5 5 5 5 5 6 5 5 5 2 201 199 199 19...
# 12  4 4 4 4 3 3 4 4 4 4 4 204 204 204 204 205 205 ...
#
#                                            allSameRle
# 2   [000155de5.jpg, 07ae92b4f.jpg, 32018f9a6.jpg, ...
# 3   [000194a2d.jpg, 285c29528.jpg, 384765ab2.jpg, ...
# 4   [000194a2d.jpg, 285c29528.jpg, 384765ab2.jpg, ...
# 5                      [000194a2d.jpg, d3d5edcf0.jpg]
# 6   [000194a2d.jpg, 285c29528.jpg, 384765ab2.jpg, ...
# 7                      [000194a2d.jpg, d3d5edcf0.jpg]
# 9       [00021ddc3.jpg, 0efbf3431.jpg, f3cd16e96.jpg]
# 10  [00021ddc3.jpg, 0efbf3431.jpg, 23d9ae03d.jpg, ...
# 11  [00021ddc3.jpg, 0efbf3431.jpg, 23d9ae03d.jpg, ...
# 12  [00021ddc3.jpg, 0efbf3431.jpg, 23d9ae03d.jpg, ...

# %%
# Verify that 'rleAndPosition' values only occurs mainly a few times 
dfWtShipOnly["rleAndPosition"].value_counts().describe()
# Out:
# count    18996.000000
# mean         4.302116
# std          2.610800
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          6.000000
# max         15.000000
# Name: rleAndPosition, dtype: float64

# %%
# Plot "allSameRle"

import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
from PIL import Image

def get_image_data(image_id, image_type, **kwargs):
    img = _get_image_data_opencv(image_id, image_type, **kwargs)
    img = img.astype('uint8')
    return img

def _get_image_data_opencv(image_id, image_type, **kwargs):
    fname = "../../data/train/images/" + image_id
    img = cv2.imread(fname)
    assert img is not None, "Failed to read image : %s, %s" % (image_id, image_type)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img

maxRepetition = 8
plt.figure(figsize=(20,20))
ImgNumber = 10
i = 0
for y in range(ImgNumber) :
    image_id = dfWtShipOnly["ImageId"].tolist()[np.random.randint(0,len(dfWtShipOnly))]
    img = get_image_data(image_id, 'Train')
    ID_list = dfWtShipOnly[dfWtShipOnly["ImageId"] == image_id]["allSameRle"].tolist()[0]
    if len(ID_list) > maxRepetition: ID_list = ID_list[0:maxRepetition-1]
    for ID in ID_list :
        i += 1
        img = get_image_data(ID, 'Train')
        plt.subplot(ImgNumber,maxRepetition,i)
        plt.imshow(img, cmap='binary')
    i = maxRepetition * (y+1)

# %%
# Group the 'rleAndPosition' by ImageId  
dfWtShipOnlyUnique = dfWtShipOnly.groupby('ImageId')['allSameRle'].apply(lambda x: set(x.sum()))

# %%
print(len(df))
print(len(dfWtShipOnly))
print(len(dfWtShipOnlyUnique))
# Out:
# 231723
# 81723
# 8635

# %%
print(len(dfWtShipOnlyUnique))
alreadyDropped = []
dfWtShipOnlyUniqueCopy = dfWtShipOnlyUnique
for itemKeeped in dfWtShipOnlyUnique.iteritems() :
    if not itemKeeped[0] in alreadyDropped :
        for itemToCheck in dfWtShipOnlyUnique.iteritems() :
            if itemToCheck[0] in itemKeeped[1] and not itemToCheck[0] in alreadyDropped and itemToCheck[0] != itemKeeped[0]:
                dfWtShipOnlyUnique = dfWtShipOnlyUnique.drop(itemToCheck[0])  
                alreadyDropped = alreadyDropped + [itemToCheck[0]]
print(len(dfWtShipOnlyUnique))
# Out:
# 42556
# 8635

# %%
allUniqLabels = dfWtShipOnly.loc[[True if ID in dfWtShipOnlyUnique.index else False for ID in dfWtShipOnly["ImageId"]]]
allUniqLabels.to_csv('../../data/train/cleaned.csv', index=False)

# %%
from sklearn.model_selection import KFold # import KFold
X = np.array([[1, 2], [3, 4], [1, 2], [3, 4]]) # create an array
y = np.array([1, 2, 3, 4]) # Create another array
kf = KFold(n_splits=5, random_state=22, shuffle=False) # Define the split - into 2 folds 
kf.get_n_splits(X) # returns the number of splitting iterations in the cross-validator

print(kf)
# Out:
# KFold(n_splits=5, random_state=22, shuffle=False)
